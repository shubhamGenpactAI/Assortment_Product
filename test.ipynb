# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
# connection details
username = "postgres"
password = "284241"
host = "localhost"
port = "5432"
database = "Assortment"

# %%
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# %%
with engine.connect() as conn:
    result = conn.execute(text('SELECT * FROM "inventory_report"'))
    df = pd.DataFrame(result.fetchall(), columns=result.keys())
print(df.head())
# Out:
#          date store_id   sku_id  inventory_on_hand  stockout_flag  \
# 0  2026-01-06     ST06  SKU0015                  0           True
# 1  2026-02-06     ST06  SKU0044                  1           True
# 2  2026-03-30     ST04  SKU0013                  2           True
# 3  2026-03-17     ST06  SKU0044                  1           True
# 4  2026-02-16     ST09  SKU0049                  7          False
#
#   days_of_supply inventory_value     sku_store
# 0            0.0               0  ST06_SKU0015
# 1            1.2               1  ST06_SKU0044
# 2            1.6               2  ST04_SKU0013
# 3            0.3               1  ST06_SKU0044
# 4            3.8               7  ST09_SKU0049
